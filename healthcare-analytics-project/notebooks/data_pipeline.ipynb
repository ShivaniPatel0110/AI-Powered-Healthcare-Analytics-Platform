# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv("C:/data.csv")

# %%
print (df.head())
# Out:
#    provider_ccn                         hospital_name            city state  \
# 0        110130                 IRWIN COUNTY HOSPITAL          OCILLA    GA
# 1        144042              LAKE BEHAVIORAL HOSPITAL        WAUKEGAN    IL
# 2         43036  EVEREST REHABILITATION HOSPITAL BENT          ROGERS    AR
# 3        454155  OCEANS BEHAVIORAL HOSPITAL CORPUS CH  CORPUS CHRISTI    TX
# 4        421303        WILLIAMSBURG REGIONAL HOSPITAL       KINGSTREE    SC
#
#    total_discharges  number_of_beds   \
# 0                77               64
# 1              1057              161
# 2                63               36
# 3               137               42
# 4                90               25
#
#    hospital_number_of_beds_for_adults_and_peds  bed_days_available   \
# 0                                         34.0                 2108
# 1                                        161.0                14812
# 2                                         36.0                 2124
# 3                                         42.0                 1890
# 4                                         21.0                 2289
#
#    fte_employees   interns_residents   ...  inpatient_charges  \
# 0           97.15                 0.0  ...            1892400
# 1          227.95                 0.0  ...           22372700
# 2           74.54                 0.0  ...            2948357
# 3           68.01                 0.0  ...            1703505
# 4          181.03                 0.0  ...            3388938
#
#    outpatient_charges  net_patient_revenue  total_operating_expense  \
# 0             3881115              1557790                  3033643
# 1              960619              9784298                  8585822
# 2               34172              1450453                  2447938
# 3                   0              1261761                  3445228
# 4            10205503              5422988                  8676352
#
#    net_income  cost_per_discharges  revenue_efficiency  profit_margin  \
# 0    -1248820         31993.012990        20231.038960        -80.17%
# 1     2632879          7674.041627         9256.667928         26.91%
# 2     -518505         44372.063490        23023.063490        -35.75%
# 3    -2183297         14348.145990         9209.934307       -173.04%
# 4    -3260557         83372.811110        60255.422220        -60.12%
#
#   bed_utilization  staff_efficiency
# 0        1.203125          0.792589
# 1        6.565217          4.636982
# 2        1.750000          0.845184
# 3        3.261905          2.014410
# 4        3.600000          0.497155
#
# [5 rows x 21 columns]

# %%
from sqlalchemy import create_engine
engine = create_engine("postgresql://postgres:postgres123@localhost:5432/healthcare_analytics")

# %%
df.to_sql("hospital_data",engine, if_exists="replace",index=False)
# Out:
# 734
